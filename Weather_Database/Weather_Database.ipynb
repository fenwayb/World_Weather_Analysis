# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

import time
import winsound

from scipy.stats import linregress
from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# generate 2000 random coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#zips two arrays into a tuple object
lat_lngs = zip(lats, lngs)

#define coordinates
coordinates = list(lat_lngs)

# %%
#checks that it generated enough unique cities and stores them as a list
 
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #checks if the city isn't already on the list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 760

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval")
line = ("-"*25)
print(line)

# Create counters.
record_count = 1
set_count = 1

# define url parameters
url = "http://api.openweathermap.org/data/2.5/weather?"
params={"appid": weather_api_key, "units":"Imperial"}

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        params["q"]=city
        city_weather = requests.get(url, params=params).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print(line)
print("Data Retrieval Complete      ")
print(line)

# lets me know when this section is done as it takes a while to run
duration = 1000 #milliseconds
freq = 400 #hz
winsound.Beep(freq, duration)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | pangkalanbuun
# Processing Record 5 of Set 1 | fort nelson
# Processing Record 6 of Set 1 | morondava
# Processing Record 7 of Set 1 | guerrero negro
# Processing Record 8 of Set 1 | bilibino
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | rock sound
# Processing Record 12 of Set 1 | salisbury
# Processing Record 13 of Set 1 | novorudnyy
# Processing Record 14 of Set 1 | ambilobe
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | tonder
# Processing Record 17 of Set 1 | arshan
# Processing Record 18 of Set 1 | amalapuram
# Processing Record 19 of Set 1 | aksu
# Processing Record 20 of Set 1 | beringovskiy
# Processing Record 21 of Set 1 | murray bridge
# Processing Record 22 of Set 1 | dudinka
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | korla
# Processing Record 25 of Set 1 | tefe
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | touros
# Processing Record 29 of Set 1 | maamba
# Processing Record 30 of Set 1 | lata
# Processing Record 31 of Set 1 | coquimbo
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | villablino
# Processing Record 35 of Set 1 | hovd
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | pacific grove
# Processing Record 40 of Set 1 | ilulissat
# Processing Record 41 of Set 1 | xichang
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | sabang
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | palmer
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | westport
# Processing Record 1 of Set 2 | siocon
# Processing Record 2 of Set 2 | mutsu
# Processing Record 3 of Set 2 | ponta delgada
# Processing Record 4 of Set 2 | omsukchan
# Processing Record 5 of Set 2 | sur
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | sechura
# Processing Record 8 of Set 2 | mayo
# Processing Record 9 of Set 2 | cuiluan
# Processing Record 10 of Set 2 | lompoc
# Processing Record 11 of Set 2 | vardo
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | nhulunbuy
# Processing Record 14 of Set 2 | saint george
# Processing Record 15 of Set 2 | luderitz
# Processing Record 16 of Set 2 | san quintin
# Processing Record 17 of Set 2 | naze
# Processing Record 18 of Set 2 | north myrtle beach
# Processing Record 19 of Set 2 | surt
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | sestroretsk
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 2 | biaora
# Processing Record 25 of Set 2 | tamandare
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | bengkulu
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | hamilton
# Processing Record 37 of Set 2 | jalu
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | velikie luki
# City not found. Skipping...
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | tura
# Processing Record 43 of Set 2 | tutoia
# Processing Record 44 of Set 2 | hermanus
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | namibe
# Processing Record 48 of Set 2 | nanortalik
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | egvekinot
# Processing Record 1 of Set 3 | bandarbeyla
# Processing Record 2 of Set 3 | siparia
# Processing Record 3 of Set 3 | weligama
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | unai
# Processing Record 6 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | cam ranh
# Processing Record 10 of Set 3 | margate
# Processing Record 11 of Set 3 | aklavik
# Processing Record 12 of Set 3 | padang
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | mantua
# Processing Record 15 of Set 3 | ippy
# Processing Record 16 of Set 3 | berdychiv
# Processing Record 17 of Set 3 | ostrovnoy
# Processing Record 18 of Set 3 | northam
# Processing Record 19 of Set 3 | gondanglegi
# Processing Record 20 of Set 3 | bitam
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | tazovskiy
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | brae
# Processing Record 25 of Set 3 | buin
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | nishihara
# Processing Record 32 of Set 3 | tsogni
# Processing Record 33 of Set 3 | palmas bellas
# Processing Record 34 of Set 3 | aripuana
# Processing Record 35 of Set 3 | piterka
# Processing Record 36 of Set 3 | meulaboh
# Processing Record 37 of Set 3 | bambous virieux
# Processing Record 38 of Set 3 | nagutskoye
# Processing Record 39 of Set 3 | chipinge
# Processing Record 40 of Set 3 | san jeronimo
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | mar del plata
# Processing Record 43 of Set 3 | lakatoro
# Processing Record 44 of Set 3 | carutapera
# Processing Record 45 of Set 3 | ellensburg
# Processing Record 46 of Set 3 | nampula
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | nome
# Processing Record 50 of Set 3 | mahebourg
# Processing Record 1 of Set 4 | vrangel
# Processing Record 2 of Set 4 | domoni
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | alyangula
# Processing Record 5 of Set 4 | acapulco
# Processing Record 6 of Set 4 | rohnert park
# Processing Record 7 of Set 4 | marawi
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | san cristobal
# Processing Record 10 of Set 4 | mitsamiouli
# Processing Record 11 of Set 4 | khorinsk
# Processing Record 12 of Set 4 | tatawin
# Processing Record 13 of Set 4 | toungoo
# City not found. Skipping...
# Processing Record 14 of Set 4 | bethel
# Processing Record 15 of Set 4 | albany
# Processing Record 16 of Set 4 | loubomo
# Processing Record 17 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 4 | vila franca do campo
# Processing Record 19 of Set 4 | esso
# Processing Record 20 of Set 4 | diego de almagro
# Processing Record 21 of Set 4 | rio gallegos
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | aksay
# Processing Record 24 of Set 4 | hearst
# Processing Record 25 of Set 4 | constitucion
# Processing Record 26 of Set 4 | mehamn
# Processing Record 27 of Set 4 | denpasar
# Processing Record 28 of Set 4 | mahajanga
# Processing Record 29 of Set 4 | zaozerne
# Processing Record 30 of Set 4 | belyy yar
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | souillac
# Processing Record 33 of Set 4 | lexington
# Processing Record 34 of Set 4 | storslett
# Processing Record 35 of Set 4 | sambava
# Processing Record 36 of Set 4 | moultrie
# Processing Record 37 of Set 4 | nakamura
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | kovdor
# Processing Record 40 of Set 4 | puerto quijarro
# Processing Record 41 of Set 4 | fort-shevchenko
# Processing Record 42 of Set 4 | clarence town
# Processing Record 43 of Set 4 | narsaq
# Processing Record 44 of Set 4 | havre-saint-pierre
# Processing Record 45 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 46 of Set 4 | labuhan
# Processing Record 47 of Set 4 | majene
# Processing Record 48 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 4 | chaman
# Processing Record 50 of Set 4 | coihaique
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | lasa
# Processing Record 3 of Set 5 | vicuna
# Processing Record 4 of Set 5 | ngunguru
# Processing Record 5 of Set 5 | steamboat springs
# Processing Record 6 of Set 5 | troitskoye
# Processing Record 7 of Set 5 | villefranche-de-rouergue
# Processing Record 8 of Set 5 | faya
# City not found. Skipping...
# Processing Record 9 of Set 5 | yasothon
# Processing Record 10 of Set 5 | shelburne
# Processing Record 11 of Set 5 | marsh harbour
# Processing Record 12 of Set 5 | vysotsk
# Processing Record 13 of Set 5 | hervey bay
# Processing Record 14 of Set 5 | itanagar
# Processing Record 15 of Set 5 | nyaunglebin
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | jogbani
# Processing Record 18 of Set 5 | bathsheba
# Processing Record 19 of Set 5 | gannan
# Processing Record 20 of Set 5 | baneh
# Processing Record 21 of Set 5 | byron bay
# Processing Record 22 of Set 5 | aitape
# Processing Record 23 of Set 5 | makakilo city
# Processing Record 24 of Set 5 | eyl
# Processing Record 25 of Set 5 | homer
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | kadoma
# Processing Record 28 of Set 5 | pakxe
# Processing Record 29 of Set 5 | turbat
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | sorland
# Processing Record 32 of Set 5 | velsk
# Processing Record 33 of Set 5 | norman wells
# Processing Record 34 of Set 5 | panama city
# Processing Record 35 of Set 5 | san martin
# Processing Record 36 of Set 5 | nanakuli
# Processing Record 37 of Set 5 | mount gambier
# Processing Record 38 of Set 5 | taltal
# Processing Record 39 of Set 5 | faanui
# Processing Record 40 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | rapar
# Processing Record 43 of Set 5 | jamestown
# Processing Record 44 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 5 | conceicao do araguaia
# Processing Record 46 of Set 5 | carnarvon
# Processing Record 47 of Set 5 | promysla
# City not found. Skipping...
# Processing Record 48 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 5 | henties bay
# Processing Record 50 of Set 5 | kincardine
# Processing Record 1 of Set 6 | shache
# Processing Record 2 of Set 6 | pemangkat
# Processing Record 3 of Set 6 | tandil
# Processing Record 4 of Set 6 | kahului
# Processing Record 5 of Set 6 | komsomolets
# Processing Record 6 of Set 6 | glushkovo
# Processing Record 7 of Set 6 | barra patuca
# Processing Record 8 of Set 6 | ribeira grande
# Processing Record 9 of Set 6 | araouane
# Processing Record 10 of Set 6 | zambezi
# Processing Record 11 of Set 6 | port hardy
# Processing Record 12 of Set 6 | kavieng
# Processing Record 13 of Set 6 | imbituba
# Processing Record 14 of Set 6 | leshukonskoye
# Processing Record 15 of Set 6 | tateyama
# Processing Record 16 of Set 6 | atar
# Processing Record 17 of Set 6 | rey bouba
# Processing Record 18 of Set 6 | vidim
# Processing Record 19 of Set 6 | tasiilaq
# Processing Record 20 of Set 6 | haflong
# Processing Record 21 of Set 6 | jumla
# Processing Record 22 of Set 6 | oussouye
# Processing Record 23 of Set 6 | fairbanks
# Processing Record 24 of Set 6 | half moon bay
# Processing Record 25 of Set 6 | gizo
# Processing Record 26 of Set 6 | victoria
# Processing Record 27 of Set 6 | astana
# Processing Record 28 of Set 6 | muli
# Processing Record 29 of Set 6 | umm lajj
# Processing Record 30 of Set 6 | lusambo
# Processing Record 31 of Set 6 | hami
# Processing Record 32 of Set 6 | praia
# Processing Record 33 of Set 6 | luwuk
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | scarborough
# Processing Record 36 of Set 6 | barrow
# Processing Record 37 of Set 6 | gualeguay
# Processing Record 38 of Set 6 | shimoda
# Processing Record 39 of Set 6 | dikson
# Processing Record 40 of Set 6 | nemuro
# Processing Record 41 of Set 6 | bud
# Processing Record 42 of Set 6 | batticaloa
# Processing Record 43 of Set 6 | dunedin
# Processing Record 44 of Set 6 | ust-kuyga
# Processing Record 45 of Set 6 | kharp
# Processing Record 46 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 6 | port lincoln
# Processing Record 48 of Set 6 | newala
# Processing Record 49 of Set 6 | college
# Processing Record 50 of Set 6 | waterloo
# Processing Record 1 of Set 7 | laguna
# Processing Record 2 of Set 7 | san jose
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 | dingle
# Processing Record 5 of Set 7 | winchester
# Processing Record 6 of Set 7 | kulhudhuffushi
# Processing Record 7 of Set 7 | lima
# Processing Record 8 of Set 7 | corinto
# Processing Record 9 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 7 | bodrum
# Processing Record 11 of Set 7 | tual
# Processing Record 12 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 7 | pangnirtung
# Processing Record 14 of Set 7 | kruisfontein
# Processing Record 15 of Set 7 | villa carlos paz
# Processing Record 16 of Set 7 | truth or consequences
# Processing Record 17 of Set 7 | chilca
# Processing Record 18 of Set 7 | mnogovershinnyy
# Processing Record 19 of Set 7 | yar-sale
# Processing Record 20 of Set 7 | pringsewu
# Processing Record 21 of Set 7 | tazmalt
# Processing Record 22 of Set 7 | orotukan
# Processing Record 23 of Set 7 | kozan
# Processing Record 24 of Set 7 | sao felix do xingu
# Processing Record 25 of Set 7 | port-gentil
# Processing Record 26 of Set 7 | manadhoo
# Processing Record 27 of Set 7 | eugene
# Processing Record 28 of Set 7 | serebryansk
# Processing Record 29 of Set 7 | millet
# Processing Record 30 of Set 7 | lazaro cardenas
# Processing Record 31 of Set 7 | nokaneng
# Processing Record 32 of Set 7 | jinxiang
# Processing Record 33 of Set 7 | abha
# Processing Record 34 of Set 7 | soure
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | airai
# Processing Record 37 of Set 7 | den helder
# Processing Record 38 of Set 7 | arbazh
# Processing Record 39 of Set 7 | sitka
# Processing Record 40 of Set 7 | acarau
# Processing Record 41 of Set 7 | buluang
# Processing Record 42 of Set 7 | hualmay
# Processing Record 43 of Set 7 | khatanga
# Processing Record 44 of Set 7 | vestmannaeyjar
# Processing Record 45 of Set 7 | asyut
# Processing Record 46 of Set 7 | saint anthony
# Processing Record 47 of Set 7 | bowen
# Processing Record 48 of Set 7 | montemor-o-novo
# Processing Record 49 of Set 7 | blind river
# Processing Record 50 of Set 7 | siddharthanagar
# Processing Record 1 of Set 8 | nuuk
# Processing Record 2 of Set 8 | maine-soroa
# Processing Record 3 of Set 8 | oskemen
# Processing Record 4 of Set 8 | road town
# Processing Record 5 of Set 8 | san miguelito
# Processing Record 6 of Set 8 | stepnyak
# Processing Record 7 of Set 8 | gat
# Processing Record 8 of Set 8 | emerald
# Processing Record 9 of Set 8 | georgetown
# Processing Record 10 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 11 of Set 8 | ewa beach
# Processing Record 12 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 8 | geraldton
# Processing Record 14 of Set 8 | champerico
# Processing Record 15 of Set 8 | sioux lookout
# Processing Record 16 of Set 8 | culaman
# Processing Record 17 of Set 8 | algiers
# Processing Record 18 of Set 8 | batetskiy
# Processing Record 19 of Set 8 | kaitangata
# Processing Record 20 of Set 8 | anadyr
# Processing Record 21 of Set 8 | belmonte
# Processing Record 22 of Set 8 | hasaki
# Processing Record 23 of Set 8 | iralaya
# Processing Record 24 of Set 8 | entre rios
# Processing Record 25 of Set 8 | beyneu
# Processing Record 26 of Set 8 | alamogordo
# Processing Record 27 of Set 8 | buala
# Processing Record 28 of Set 8 | santa fe
# Processing Record 29 of Set 8 | grand gaube
# Processing Record 30 of Set 8 | itarema
# Processing Record 31 of Set 8 | atsiki
# City not found. Skipping...
# Processing Record 32 of Set 8 | nyurba
# Processing Record 33 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 8 | manga
# Processing Record 35 of Set 8 | isangel
# Processing Record 36 of Set 8 | myitkyina
# Processing Record 37 of Set 8 | chara
# Processing Record 38 of Set 8 | alofi
# Processing Record 39 of Set 8 | las vegas
# Processing Record 40 of Set 8 | caravelas
# Processing Record 41 of Set 8 | vanimo
# Processing Record 42 of Set 8 | papasquiaro
# City not found. Skipping...
# Processing Record 43 of Set 8 | harbour breton
# Processing Record 44 of Set 8 | salo
# Processing Record 45 of Set 8 | muroto
# Processing Record 46 of Set 8 | poum
# Processing Record 47 of Set 8 | katangli
# Processing Record 48 of Set 8 | kununurra
# Processing Record 49 of Set 8 | boden
# Processing Record 50 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 9 | bama
# Processing Record 2 of Set 9 | teguldet
# Processing Record 3 of Set 9 | agualote
# Processing Record 4 of Set 9 | baisha
# Processing Record 5 of Set 9 | okha
# Processing Record 6 of Set 9 | maizuru
# Processing Record 7 of Set 9 | westerly
# Processing Record 8 of Set 9 | strezhevoy
# Processing Record 9 of Set 9 | witu
# Processing Record 10 of Set 9 | winneba
# Processing Record 11 of Set 9 | pisco
# Processing Record 12 of Set 9 | janovice nad uhlavou
# Processing Record 13 of Set 9 | fort saint james
# Processing Record 14 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 9 | jinzhou
# Processing Record 16 of Set 9 | sola
# Processing Record 17 of Set 9 | yaan
# Processing Record 18 of Set 9 | klaksvik
# Processing Record 19 of Set 9 | matara
# Processing Record 20 of Set 9 | rocha
# Processing Record 21 of Set 9 | shemursha
# Processing Record 22 of Set 9 | saint-augustin
# Processing Record 23 of Set 9 | saint-pierre
# Processing Record 24 of Set 9 | krizevci
# Processing Record 25 of Set 9 | ciudad real
# Processing Record 26 of Set 9 | campoverde
# Processing Record 27 of Set 9 | poso
# Processing Record 28 of Set 9 | sao gabriel da cachoeira
# Processing Record 29 of Set 9 | flinders
# Processing Record 30 of Set 9 | malanje
# Processing Record 31 of Set 9 | verkhovazhye
# Processing Record 32 of Set 9 | mansa
# Processing Record 33 of Set 9 | changji
# Processing Record 34 of Set 9 | ugoofaaru
# Processing Record 35 of Set 9 | daru
# Processing Record 36 of Set 9 | oranjemund
# Processing Record 37 of Set 9 | virtsu
# Processing Record 38 of Set 9 | abu road
# Processing Record 39 of Set 9 | neiafu
# Processing Record 40 of Set 9 | belgrade
# Processing Record 41 of Set 9 | victor harbor
# Processing Record 42 of Set 9 | longyearbyen
# Processing Record 43 of Set 9 | haimen
# Processing Record 44 of Set 9 | lixourion
# Processing Record 45 of Set 9 | kashan
# Processing Record 46 of Set 9 | kushima
# Processing Record 47 of Set 9 | doha
# Processing Record 48 of Set 9 | catalina
# Processing Record 49 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 50 of Set 9 | port macquarie
# Processing Record 1 of Set 10 | wenling
# Processing Record 2 of Set 10 | pitimbu
# Processing Record 3 of Set 10 | camabatela
# Processing Record 4 of Set 10 | dupnica
# City not found. Skipping...
# Processing Record 5 of Set 10 | bosobolo
# Processing Record 6 of Set 10 | santa vitoria do palmar
# Processing Record 7 of Set 10 | kananga
# Processing Record 8 of Set 10 | khipro
# Processing Record 9 of Set 10 | mujiayingzi
# Processing Record 10 of Set 10 | douglas
# Processing Record 11 of Set 10 | tarko-sale
# Processing Record 12 of Set 10 | aykhal
# Processing Record 13 of Set 10 | fortuna
# Processing Record 14 of Set 10 | tintigny
# Processing Record 15 of Set 10 | redding
# Processing Record 16 of Set 10 | camana
# Processing Record 17 of Set 10 | ljungby
# Processing Record 18 of Set 10 | nha trang
# Processing Record 19 of Set 10 | moron
# Processing Record 20 of Set 10 | kunming
# Processing Record 21 of Set 10 | tirau
# Processing Record 22 of Set 10 | huarmey
# Processing Record 23 of Set 10 | burica
# City not found. Skipping...
# Processing Record 24 of Set 10 | menongue
# Processing Record 25 of Set 10 | deputatskiy
# Processing Record 26 of Set 10 | talara
# Processing Record 27 of Set 10 | yulara
# Processing Record 28 of Set 10 | bandundu
# Processing Record 29 of Set 10 | alpinopolis
# Processing Record 30 of Set 10 | katsuura
# Processing Record 31 of Set 10 | lodwar
# Processing Record 32 of Set 10 | kibre mengist
# Processing Record 33 of Set 10 | yining
# Processing Record 34 of Set 10 | sao joao da barra
# Processing Record 35 of Set 10 | devonport
# Processing Record 36 of Set 10 | bay roberts
# Processing Record 37 of Set 10 | lavrentiya
# Processing Record 38 of Set 10 | langres
# Processing Record 39 of Set 10 | port hedland
# Processing Record 40 of Set 10 | orchard homes
# Processing Record 41 of Set 10 | rafaela
# Processing Record 42 of Set 10 | rawson
# Processing Record 43 of Set 10 | viedma
# Processing Record 44 of Set 10 | boa vista
# Processing Record 45 of Set 10 | kamphaeng phet
# Processing Record 46 of Set 10 | hamamatsu
# Processing Record 47 of Set 10 | mildura
# Processing Record 48 of Set 10 | pandharpur
# Processing Record 49 of Set 10 | shizunai
# Processing Record 50 of Set 10 | nizwa
# Processing Record 1 of Set 11 | iqaluit
# Processing Record 2 of Set 11 | tiznit
# Processing Record 3 of Set 11 | pustoshka
# Processing Record 4 of Set 11 | chumikan
# Processing Record 5 of Set 11 | baruun-urt
# Processing Record 6 of Set 11 | mattru
# Processing Record 7 of Set 11 | mogadishu
# Processing Record 8 of Set 11 | urusha
# Processing Record 9 of Set 11 | taoudenni
# Processing Record 10 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 11 | igunga
# Processing Record 12 of Set 11 | komsomolskiy
# Processing Record 13 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 14 of Set 11 | gusau
# Processing Record 15 of Set 11 | garmsar
# Processing Record 16 of Set 11 | golden
# Processing Record 17 of Set 11 | cedar city
# Processing Record 18 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 11 | waddan
# Processing Record 20 of Set 11 | pyinmana
# Processing Record 21 of Set 11 | boromo
# Processing Record 22 of Set 11 | rosignol
# Processing Record 23 of Set 11 | iberia
# Processing Record 24 of Set 11 | canakkale
# Processing Record 25 of Set 11 | dubbo
# Processing Record 26 of Set 11 | nabire
# Processing Record 27 of Set 11 | teeli
# Processing Record 28 of Set 11 | bosaso
# Processing Record 29 of Set 11 | tayu
# Processing Record 30 of Set 11 | imeni poliny osipenko
# Processing Record 31 of Set 11 | shu
# Processing Record 32 of Set 11 | la ronge
# Processing Record 33 of Set 11 | traismauer
# Processing Record 34 of Set 11 | muscat
# Processing Record 35 of Set 11 | karatuzskoye
# Processing Record 36 of Set 11 | xining
# Processing Record 37 of Set 11 | celano
# Processing Record 38 of Set 11 | hofn
# Processing Record 39 of Set 11 | pelym
# Processing Record 40 of Set 11 | riyadh
# Processing Record 41 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 11 | palana
# Processing Record 43 of Set 11 | mbekenyera
# Processing Record 44 of Set 11 | batasan
# Processing Record 45 of Set 11 | bossembele
# City not found. Skipping...
# Processing Record 46 of Set 11 | malindi
# Processing Record 47 of Set 11 | bongandanga
# Processing Record 48 of Set 11 | merrill
# Processing Record 49 of Set 11 | tianjin
# Processing Record 50 of Set 11 | skjervoy
# Processing Record 1 of Set 12 | ahipara
# Processing Record 2 of Set 12 | namatanai
# Processing Record 3 of Set 12 | kyshtovka
# Processing Record 4 of Set 12 | forrest city
# Processing Record 5 of Set 12 | glasgow
# Processing Record 6 of Set 12 | djambala
# Processing Record 7 of Set 12 | khandyga
# Processing Record 8 of Set 12 | stephenville
# Processing Record 9 of Set 12 | nizhnyaya omka
# Processing Record 10 of Set 12 | nivala
# Processing Record 11 of Set 12 | guiong
# Processing Record 12 of Set 12 | great falls
# Processing Record 13 of Set 12 | diemen
# Processing Record 14 of Set 12 | vila velha
# Processing Record 15 of Set 12 | alice town
# Processing Record 16 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 17 of Set 12 | livingston
# Processing Record 18 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 12 | tommot
# Processing Record 20 of Set 12 | coahuayana
# Processing Record 21 of Set 12 | charters towers
# Processing Record 22 of Set 12 | qasigiannguit
# Processing Record 23 of Set 12 | bali
# Processing Record 24 of Set 12 | san rafael
# Processing Record 25 of Set 12 | dalbandin
# Processing Record 26 of Set 12 | landerneau
# Processing Record 27 of Set 12 | trofors
# Processing Record 28 of Set 12 | oschatz
# Processing Record 29 of Set 12 | obo
# Processing Record 30 of Set 12 | clyde river
# Processing Record 31 of Set 12 | haines junction
# Processing Record 32 of Set 12 | high level
# Processing Record 33 of Set 12 | comodoro rivadavia
# Processing Record 34 of Set 12 | joshimath
# Processing Record 35 of Set 12 | usinsk
# Processing Record 36 of Set 12 | graaff-reinet
# Processing Record 37 of Set 12 | aswan
# Processing Record 38 of Set 12 | stromness
# Processing Record 39 of Set 12 | gumdag
# Processing Record 40 of Set 12 | kaeo
# Processing Record 41 of Set 12 | sao paulo de olivenca
# Processing Record 42 of Set 12 | ebbw vale
# Processing Record 43 of Set 12 | kropotkin
# Processing Record 44 of Set 12 | saquarema
# Processing Record 45 of Set 12 | tautira
# Processing Record 46 of Set 12 | naryan-mar
# Processing Record 47 of Set 12 | tagusao
# Processing Record 48 of Set 12 | santa isabel do rio negro
# Processing Record 49 of Set 12 | cheyenne
# Processing Record 50 of Set 12 | vostok
# Processing Record 1 of Set 13 | wanaka
# Processing Record 2 of Set 13 | moyale
# Processing Record 3 of Set 13 | sonoita
# Processing Record 4 of Set 13 | tarauaca
# Processing Record 5 of Set 13 | gao
# Processing Record 6 of Set 13 | guiglo
# Processing Record 7 of Set 13 | normandin
# Processing Record 8 of Set 13 | sombrerete
# Processing Record 9 of Set 13 | nara
# Processing Record 10 of Set 13 | broome
# Processing Record 11 of Set 13 | requena
# Processing Record 12 of Set 13 | vao
# Processing Record 13 of Set 13 | zhezkazgan
# Processing Record 14 of Set 13 | kupang
# Processing Record 15 of Set 13 | itaueira
# Processing Record 16 of Set 13 | havelock
# Processing Record 17 of Set 13 | buchanan
# Processing Record 18 of Set 13 | batagay-alyta
# Processing Record 19 of Set 13 | omutinskoye
# City not found. Skipping...
# Processing Record 20 of Set 13 | liverpool
# Processing Record 21 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 13 | richards bay
# Processing Record 23 of Set 13 | cherskiy
# Processing Record 24 of Set 13 | inuvik
# Processing Record 25 of Set 13 | juegang
# Processing Record 26 of Set 13 | moerai
# Processing Record 27 of Set 13 | waipawa
# Processing Record 28 of Set 13 | hammerfest
# Processing Record 29 of Set 13 | mbalmayo
# Processing Record 30 of Set 13 | roald
# Processing Record 31 of Set 13 | ninghai
# Processing Record 32 of Set 13 | mandera
# Processing Record 33 of Set 13 | octeville
# Processing Record 34 of Set 13 | chadan
# Processing Record 35 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 36 of Set 13 | husavik
# Processing Record 37 of Set 13 | coxim
# Processing Record 38 of Set 13 | california city
# Processing Record 39 of Set 13 | seoul
# Processing Record 40 of Set 13 | miri
# Processing Record 41 of Set 13 | kysyl-syr
# Processing Record 42 of Set 13 | maputo
# Processing Record 43 of Set 13 | albanel
# Processing Record 44 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 13 | jalingo
# Processing Record 46 of Set 13 | svetlyy
# Processing Record 47 of Set 13 | horadiz
# Processing Record 48 of Set 13 | bichena
# Processing Record 49 of Set 13 | diebougou
# Processing Record 50 of Set 13 | talnakh
# Processing Record 1 of Set 14 | buraydah
# Processing Record 2 of Set 14 | galesong
# Processing Record 3 of Set 14 | lincoln
# Processing Record 4 of Set 14 | awbari
# Processing Record 5 of Set 14 | shingu
# Processing Record 6 of Set 14 | capao da canoa
# Processing Record 7 of Set 14 | whitehorse
# Processing Record 8 of Set 14 | grand baie
# Processing Record 9 of Set 14 | banda aceh
# Processing Record 10 of Set 14 | bonfim
# Processing Record 11 of Set 14 | gawler
# Processing Record 12 of Set 14 | saint-francois
# Processing Record 13 of Set 14 | eregli
# Processing Record 14 of Set 14 | asau
# Processing Record 15 of Set 14 | shasta lake
# Processing Record 16 of Set 14 | kinshasa
# Processing Record 17 of Set 14 | warrington
# Processing Record 18 of Set 14 | eretria
# Processing Record 19 of Set 14 | kashi
# Processing Record 20 of Set 14 | lagoa
# Processing Record 21 of Set 14 | dongsheng
# Processing Record 22 of Set 14 | wallaceburg
# Processing Record 23 of Set 14 | ancud
# Processing Record 24 of Set 14 | chapada dos guimaraes
# Processing Record 25 of Set 14 | nacala
# Processing Record 26 of Set 14 | loukhi
# Processing Record 27 of Set 14 | mitu
# Processing Record 28 of Set 14 | waingapu
# Processing Record 29 of Set 14 | avera
# Processing Record 30 of Set 14 | bolonchen
# City not found. Skipping...
# Processing Record 31 of Set 14 | ixtapa
# Processing Record 32 of Set 14 | mgandu
# Processing Record 33 of Set 14 | almeirim
# Processing Record 34 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 35 of Set 14 | puerto madryn
# Processing Record 36 of Set 14 | kimparana
# Processing Record 37 of Set 14 | kaduqli
# Processing Record 38 of Set 14 | mehran
# Processing Record 39 of Set 14 | perivolion
# Processing Record 40 of Set 14 | tsentralnyy
# City not found. Skipping...
# Processing Record 41 of Set 14 | chicama
# Processing Record 42 of Set 14 | adrar
# Processing Record 43 of Set 14 | sheltozero
# Processing Record 44 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 46 of Set 14 | yambio
# Processing Record 47 of Set 14 | wuwei
# Processing Record 48 of Set 14 | sao joao del rei
# Processing Record 49 of Set 14 | artyom
# Processing Record 50 of Set 14 | omaruru
# Processing Record 1 of Set 15 | san pedro
# Processing Record 2 of Set 15 | groton
# Processing Record 3 of Set 15 | mookane
# Processing Record 4 of Set 15 | anchorage
# Processing Record 5 of Set 15 | cravo norte
# Processing Record 6 of Set 15 | hirna
# Processing Record 7 of Set 15 | filingue
# Processing Record 8 of Set 15 | churapcha
# Processing Record 9 of Set 15 | atlantic city
# Processing Record 10 of Set 15 | ust-koksa
# Processing Record 11 of Set 15 | devarkonda
# Processing Record 12 of Set 15 | kyaukse
# Processing Record 13 of Set 15 | chapais
# Processing Record 14 of Set 15 | dhidhdhoo
# Processing Record 15 of Set 15 | newton
# Processing Record 16 of Set 15 | balkhash
# Processing Record 17 of Set 15 | belaya gora
# Processing Record 18 of Set 15 | gamba
# Processing Record 19 of Set 15 | rio grande
# Processing Record 20 of Set 15 | ha
# City not found. Skipping...
# Processing Record 21 of Set 15 | pionerskiy
# Processing Record 22 of Set 15 | cozumel
# Processing Record 23 of Set 15 | nimaparha
# Processing Record 24 of Set 15 | makhinjauri
# Processing Record 25 of Set 15 | katobu
# Processing Record 26 of Set 15 | pangai
# Processing Record 27 of Set 15 | bereznik
# Processing Record 28 of Set 15 | enkhuizen
# Processing Record 29 of Set 15 | concarneau
# Processing Record 30 of Set 15 | the valley
# Processing Record 31 of Set 15 | baoro
# Processing Record 32 of Set 15 | sulurpeta
# City not found. Skipping...
# Processing Record 33 of Set 15 | bardiyah
# Processing Record 34 of Set 15 | shaunavon
# Processing Record 35 of Set 15 | himora
# City not found. Skipping...
# Processing Record 36 of Set 15 | korogwe
# City not found. Skipping...
# Processing Record 37 of Set 15 | mascote
# Processing Record 38 of Set 15 | grindavik
# Processing Record 39 of Set 15 | ormara
# Processing Record 40 of Set 15 | roma
# Processing Record 41 of Set 15 | nelidovo
# Processing Record 42 of Set 15 | piranshahr
# Processing Record 43 of Set 15 | puerto escondido
# Processing Record 44 of Set 15 | estelle
# Processing Record 45 of Set 15 | otavi
# Processing Record 46 of Set 15 | verkhniy avzyan
# Processing Record 47 of Set 15 | gejiu
# Processing Record 48 of Set 15 | lewisville
# Processing Record 49 of Set 15 | gull lake
# Processing Record 50 of Set 15 | fushun
# Processing Record 1 of Set 16 | grenfell
# Processing Record 2 of Set 16 | hereford
# Processing Record 3 of Set 16 | saint pete beach
# Processing Record 4 of Set 16 | jieshi
# Processing Record 5 of Set 16 | phek
# Processing Record 6 of Set 16 | tamiahua
# Processing Record 7 of Set 16 | tevaitoa
# Processing Record 8 of Set 16 | mapiripan
# Processing Record 9 of Set 16 | dawei
# Processing Record 10 of Set 16 | mizan teferi
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Check that it looks right
city_data_df

#save to file
city_data_df.to_csv("WeatherPy_Database.csv")
